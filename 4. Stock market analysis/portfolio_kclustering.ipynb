# %%
import pandas as pd

# %%
df = pd.read_csv('../Web scrapper/data/portfolio_2022-10-04.csv')
df
# Out:
#     Unnamed: 0 Ticker  Enterprise Value  Trailing P/E  Forward P/E  \
# 0            0   TSLA      8.189000e+13         95.76        45.05
# 1            1    TTD      2.874000e+12        868.57        52.36
# 2            2   NVDA      2.969200e+13         39.67        36.10
# 3            3   GOOG      1.150000e+14         17.91        15.92
# 4            4   CRWD      3.692000e+12          0.00       136.99
# 5            5   AMZN      1.220000e+14        101.76        46.95
# 6            6   IDXX      2.901000e+12         42.92        35.59
# 7            7   MELI      4.348000e+12        175.75        72.99
# 8            8   ABNB      6.069000e+12         53.06        37.04
# 9            9     ZS      2.283000e+12          0.00       140.85
# 10          10   ASML      1.692600e+13         31.69        22.27
# 11          11     SE      2.750000e+12          0.00         0.00
# 12          12   AXON      7.760000e+11         56.51        43.10
# ...
