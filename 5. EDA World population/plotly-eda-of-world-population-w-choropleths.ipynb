# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # (Plotly) EDA of World Population
# We will explore using Plotly to conduct an EDA on the data.
# Some of the items we will explore:
# 1. Plotly Express
# 2. Plotly Graph Object
# 3. Interactive choropleth with animation slider
# 5. Multiple choropleths

# %%
wp_df = pd.read_csv('world_population.csv')
wp_df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0         10694796         12486631         10752971      652230
# 1          3295066          2941651          2324731       28748
# 2         25518074         18739378         13795915     2381741
# 3            47818            32886            27075         199
# 4            53569            35611            19860         468
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# 1            98.8702       0.9957                         0.04
# 2            18.8531       1.0164                         0.56
# 3           222.4774       0.9831                         0.00
# 4           170.5641       1.0100                         0.00

# %% [markdown]
# # Cleaning the dataframes
# 1. Checking for unique and null values
# 2. Renaming,sorting the columns
# 3. Overview of top 10 countries by population
# 4. Overview of Continents

# %%
uniques = wp_df.nunique() #234 unique countries
nulls = wp_df.isnull().sum() #no null values
dtypes = wp_df.dtypes #appropriate data types

summary_df = pd.concat([uniques, nulls, dtypes],axis = 1)
summary_df.columns = ['Unique Values', 'Null Values', 'Data Types']
summary_df
# Out:
#                              Unique Values  Null Values Data Types
# Rank                                   234            0      int64
# CCA3                                   234            0     object
# Country                                234            0     object
# Capital                                234            0     object
# Continent                                6            0     object
# 2022 Population                        234            0      int64
# 2020 Population                        234            0      int64
# 2015 Population                        234            0      int64
# 2010 Population                        234            0      int64
# 2000 Population                        234            0      int64
# 1990 Population                        234            0      int64
# 1980 Population                        234            0      int64
# 1970 Population                        234            0      int64
# Area (km²)                             233            0      int64
# Density (per km²)                      234            0    float64
# Growth Rate                            180            0    float64
# World Population Percentage             70            0    float64

# %% [markdown]
# # Overview of top 10 Countries by Population
# * China, India, and USA lead the world population in percentage'
# * Pakistan, Nigeria and Bangladesh have the highest growth rates
# * Density is really high in India and Bangladesh

# %%
wp_df.columns = ['Rank','ISO-3','Country','Capital','Continent','2022','2020','2015',
                 '2010','2000','1990','1980','1970','Area (km²)','Density (per km²)','Growth Rate',
                 'World Population Percentage']
wp_df = wp_df[['Rank','ISO-3','Country','Capital','Continent', 'Area (km²)','Density (per km²)',
              'Growth Rate', 'World Population Percentage','2022','2020','2015','2010','2000','1990',
              '1980','1970']]
rank = wp_df['Rank'] <=10
top10_df = wp_df[rank]
top10_df = top10_df.sort_values(by='Rank')
top10_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_b24ac_row0_col0, #T_b24ac_row7_col5, #T_b24ac_row8_col6, #T_b24ac_row8_col7, #T_b24ac_row9_col8, #T_b24ac_row9_col9, #T_b24ac_row9_col10, #T_b24ac_row9_col11, #T_b24ac_row9_col12, #T_b24ac_row9_col13, #T_b24ac_row9_col14, #T_b24ac_row9_col15, #T_b24ac_row9_col16 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b24ac_row0_col5 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_b24ac_row0_col6, #T_b24ac_row3_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_b24ac_row0_col7, #T_b24ac_row3_col5, #T_b24ac_row3_col13, #T_b24ac_row8_col16 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b24ac_row0_col8, #T_b24ac_row0_col9, #T_b24ac_row0_col10, #T_b24ac_row0_col11, #T_b24ac_row0_col12, #T_b24ac_row0_col13, #T_b24ac_row0_col14, #T_b24ac_row0_col15, #T_b24ac_row0_col16, #T_b24ac_row5_col7, #T_b24ac_row7_col6, #T_b24ac_row8_col5, #T_b24ac_row9_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col0, #T_b24ac_row3_col10 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_b24ac_row1_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_b24ac_row1_col6 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_b24ac_row1_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_b24ac_row1_col8, #T_b24ac_row1_col9 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col10 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col11 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col12 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col13 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col14 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col15 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_b24ac_row1_col16 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_b24ac_row2_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_b24ac_row2_col5 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_b24ac_row2_col6, #T_b24ac_row7_col13, #T_b24ac_row7_col14, #T_b24ac_row8_col12 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_b24ac_row2_col7 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_b24ac_row2_col8, #T_b24ac_row2_col9, #T_b24ac_row2_col10, #T_b24ac_row2_col11, #T_b24ac_row2_col12 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_b24ac_row2_col13 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_b24ac_row2_col14 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_b24ac_row2_col15 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_b24ac_row2_col16 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_b24ac_row3_col0, #T_b24ac_row9_col7 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_b24ac_row3_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_b24ac_row3_col8, #T_b24ac_row3_col9 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_b24ac_row3_col11, #T_b24ac_row3_col12, #T_b24ac_row9_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_b24ac_row3_col14 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_b24ac_row3_col15, #T_b24ac_row3_col16, #T_b24ac_row4_col8, #T_b24ac_row4_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_b24ac_row4_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_b24ac_row4_col5, #T_b24ac_row4_col13, #T_b24ac_row5_col5, #T_b24ac_row5_col11, #T_b24ac_row9_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_b24ac_row4_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_b24ac_row4_col7 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_b24ac_row4_col10, #T_b24ac_row8_col15 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_b24ac_row4_col11 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_b24ac_row4_col12, #T_b24ac_row5_col10, #T_b24ac_row6_col14 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_b24ac_row4_col14, #T_b24ac_row7_col8, #T_b24ac_row7_col9, #T_b24ac_row7_col10 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_b24ac_row4_col15, #T_b24ac_row5_col14, #T_b24ac_row6_col6, #T_b24ac_row7_col15, #T_b24ac_row8_col8, #T_b24ac_row8_col9, #T_b24ac_row8_col10, #T_b24ac_row8_col11 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b24ac_row4_col16 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_b24ac_row5_col0 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_b24ac_row5_col6 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_b24ac_row5_col8, #T_b24ac_row5_col9, #T_b24ac_row6_col8, #T_b24ac_row6_col9, #T_b24ac_row6_col10, #T_b24ac_row6_col11, #T_b24ac_row6_col12, #T_b24ac_row6_col13 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_b24ac_row5_col12, #T_b24ac_row8_col13 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b24ac_row5_col13, #T_b24ac_row7_col16 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_b24ac_row5_col15, #T_b24ac_row5_col16 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_b24ac_row6_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_b24ac_row6_col5 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_b24ac_row6_col7 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_b24ac_row6_col15, #T_b24ac_row6_col16, #T_b24ac_row8_col14 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_b24ac_row7_col0 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_b24ac_row7_col7 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_b24ac_row7_col11, #T_b24ac_row7_col12 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_b24ac_row8_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b24ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b24ac_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_b24ac_level0_col1" class="col_heading level0 col1" >ISO-3</th>
#       <th id="T_b24ac_level0_col2" class="col_heading level0 col2" >Country</th>
#       <th id="T_b24ac_level0_col3" class="col_heading level0 col3" >Capital</th>
#       <th id="T_b24ac_level0_col4" class="col_heading level0 col4" >Continent</th>
#       <th id="T_b24ac_level0_col5" class="col_heading level0 col5" >Area (km²)</th>
#       <th id="T_b24ac_level0_col6" class="col_heading level0 col6" >Density (per km²)</th>
#       <th id="T_b24ac_level0_col7" class="col_heading level0 col7" >Growth Rate</th>
#       <th id="T_b24ac_level0_col8" class="col_heading level0 col8" >World Population Percentage</th>
#       <th id="T_b24ac_level0_col9" class="col_heading level0 col9" >2022</th>
#       <th id="T_b24ac_level0_col10" class="col_heading level0 col10" >2020</th>
#       <th id="T_b24ac_level0_col11" class="col_heading level0 col11" >2015</th>
#       <th id="T_b24ac_level0_col12" class="col_heading level0 col12" >2010</th>
#       <th id="T_b24ac_level0_col13" class="col_heading level0 col13" >2000</th>
#       <th id="T_b24ac_level0_col14" class="col_heading level0 col14" >1990</th>
#       <th id="T_b24ac_level0_col15" class="col_heading level0 col15" >1980</th>
#       <th id="T_b24ac_level0_col16" class="col_heading level0 col16" >1970</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b24ac_level0_row0" class="row_heading level0 row0" >41</th>
#       <td id="T_b24ac_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b24ac_row0_col1" class="data row0 col1" >CHN</td>
#       <td id="T_b24ac_row0_col2" class="data row0 col2" >China</td>
#       <td id="T_b24ac_row0_col3" class="data row0 col3" >Beijing</td>
#       <td id="T_b24ac_row0_col4" class="data row0 col4" >Asia</td>
#       <td id="T_b24ac_row0_col5" class="data row0 col5" >9706961</td>
#       <td id="T_b24ac_row0_col6" class="data row0 col6" >146.893300</td>
#       <td id="T_b24ac_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_b24ac_row0_col8" class="data row0 col8" >17.880000</td>
#       <td id="T_b24ac_row0_col9" class="data row0 col9" >1425887337</td>
#       <td id="T_b24ac_row0_col10" class="data row0 col10" >1424929781</td>
#       <td id="T_b24ac_row0_col11" class="data row0 col11" >1393715448</td>
#       <td id="T_b24ac_row0_col12" class="data row0 c

# %%
fig = px.histogram(wp_df, x="Growth Rate", color = 'Country', 
                   color_discrete_sequence = px.colors.sequential.Plotly3,
                   title= 'Distribution of Growth rates by Country')
fig.show()
# Out:
# <div>                            <div id="ef2ebfff-9b10-4154-8618-a0f501b6f70a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef2ebfff-9b10-4154-8618-a0f501b6f70a")) {                    Plotly.newPlot(                        "ef2ebfff-9b10-4154-8618-a0f501b6f70a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Afghanistan<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#0508b8","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"x":[1.0257],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Albania<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Albania","marker":{"color":"#1910d8","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"x":[0.9957],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Algeria<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#3c19f0","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"x":[1.0164],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=American Samoa<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"American Samoa","marker":{"color":"#6b1cfb","pattern":{"shape":""}},"name":"American Samoa","offsetgroup":"American Samoa","orientation":"v","showlegend":true,"x":[0.9831],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Andorra<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#981cfd","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"x":[1.01],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Angola<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Angola","marker":{"color":"#bf1cfd","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"x":[1.0315],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Anguilla<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#dd2bfd","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"x":[1.0066],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Antigua and Barbuda<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#f246fe","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[1.0058],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Argentina<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Argentina","marker":{"color":"#fc67fd","pattern":{"shape":""}},"name":"Argentina","offsetgroup":"Argentina","orientation":"v","showlegend":true,"x":[1.0052],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Country=Armenia<br>Growth Rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#fe88fc","pattern":{"shape":""}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"x":[0.9962],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x"," ...

# %% [markdown]
# # Overview of Continent Population Growth over the years
# 1. Groupby Continent.
# 2. Plotly Area plot

# %%
format_dic = {
    'Africa': '{:,}',
    'Asia': '{:,}',
    'Europe': '{:,}',
    'North America': '{:,}',
    'Oceania': '{:,}',
    'South America': '{:,}'
}

wp_df_gb = wp_df[['Continent', '1970','1980','1990','2000',
                  '2010','2015','2020','2022']]
wp_df_gb = wp_df_gb.groupby('Continent')
wp_df_gb = wp_df_gb.sum()
wp_df_gb = wp_df_gb.T
(wp_df_gb
 .style
 .background_gradient(vmin = 0, vmax = 1000000000)
 .format(format_dic)
)
# Out:
# <style type="text/css">
# #T_6e049_row0_col0 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_6e049_row0_col1, #T_6e049_row1_col1, #T_6e049_row2_col1, #T_6e049_row3_col1, #T_6e049_row4_col0, #T_6e049_row4_col1, #T_6e049_row5_col0, #T_6e049_row5_col1, #T_6e049_row6_col0, #T_6e049_row6_col1, #T_6e049_row7_col0, #T_6e049_row7_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6e049_row0_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_6e049_row0_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_6e049_row0_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_6e049_row0_col5 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_6e049_row1_col0 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_6e049_row1_col2 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_6e049_row1_col3 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_6e049_row1_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_6e049_row1_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_6e049_row2_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_6e049_row2_col2 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_6e049_row2_col3 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_6e049_row2_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_6e049_row2_col5 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_6e049_row3_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_6e049_row3_col2 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_6e049_row3_col3 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_6e049_row3_col4 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_6e049_row3_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_6e049_row4_col2 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_6e049_row4_col3 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_6e049_row4_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_6e049_row4_col5 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_6e049_row5_col2 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_6e049_row5_col3 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_6e049_row5_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_6e049_row5_col5 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_6e049_row6_col2, #T_6e049_row7_col2 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_6e049_row6_col3 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_6e049_row6_col4, #T_6e049_row7_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_6e049_row6_col5 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_6e049_row7_col3 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_6e049_row7_col5 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# </style>
# <table id="T_6e049">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Continent</th>
#       <th id="T_6e049_level0_col0" class="col_heading level0 col0" >Africa</th>
#       <th id="T_6e049_level0_col1" class="col_heading level0 col1" >Asia</th>
#       <th id="T_6e049_level0_col2" class="col_heading level0 col2" >Europe</th>
#       <th id="T_6e049_level0_col3" class="col_heading level0 col3" >North America</th>
#       <th id="T_6e049_level0_col4" class="col_heading level0 col4" >Oceania</th>
#       <th id="T_6e049_level0_col5" class="col_heading level0 col5" >South America</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e049_level0_row0" class="row_heading level0 row0" >1970</th>
#       <td id="T_6e049_row0_col0" class="data row0 col0" >365,444,348</td>
#       <td id="T_6e049_row0_col1" class="data row0 col1" >2,144,906,290</td>
#       <td id="T_6e049_row0_col2" class="data row0 col2" >655,923,991</td>
#       <td id="T_6e049_row0_col3" class="data row0 col3" >315,434,606</td>
#       <td id="T_6e049_row0_col4" class="data row0 col4" >19,480,270</td>
#       <td id="T_6e049_row0_col5" class="data row0 col5" >192,947,156</td>
#     </tr>
#     <tr>
#       <th id="T_6e049_level0_row1" class="row_heading level0 row1" >1980</th>
#       <td id="T_6e049_row1_col0" class="data row1 col0" >481,536,377</td>
#       <td id="T_6e049_row1_col1" class="data row1 col1" >2,635,334,228</td>
#       <td id="T_6e049_row1_col2" class="data row1 col2" >692,527,159</td>
#       <td id="T_6e049_row1_col3" class="data row1 col3" >368,293,361</td>
#       <td id="T_6e049_row1_col4" class="data row1 col4" >22,920,240</td>
#       <td id="T_6e049_row1_col5" class="data row1 col5" >241,789,006</td>
#     </tr>
#     <tr>
#       <th id="T_6e049_level0_row2" class="row_heading level0 row2" >1990</th>
#       <td id="T_6e049_row2_col0" class="data row2 col0" >638,150,629</td>
#       <td id="T_6e049_row2_col1" class="data row2 col1" >3,210,563,577</td>
#       <td id="T_6e049_row2_col2" class="data row2 col2" >720,320,797</td>
#       <td id="T_6e049_row2_col3" class="data row2 col3" >421,266,425</td>
#       <td id="T_6e049_row2_col4" class="data row2 col4" >26,743,822</td>
#       <td id="T_6e049_row2_col5" class="data row2 col5" >297,146,415</td>
#     </tr>
#     <tr>
#       <th id="T_6e049_level0_row3" class="row_heading level0 row3" >2000</th>
#       <td id="T_6e049_row3_col0" class="data row3 col0" >818,946,032</td>
#       <td id="T_6e049_row3_col1" class="data row3 col1" >3,735,089,604</td>
#       <td id="T_6e049_row3_col2" class="data row3 col2" >726,093,423</td>
#       <td id="T_6e049_row3_col3" class="data row3 col3" >486,069,584</td>
#       <td id="T_6e049_row3_col4" class="data row3 col4" >31,222,778</td>
#       <td id="T_6e049_row3_col5" class="data row3 col5" >349,634,282</td>
#     </tr>
#     <tr>
#       <th id="T_6e049_level0_row4" class="row_heading level0 row4" >2010</th>
#       <td id="T_6e049_row4_col0" class="data row4 col0" >1,055,228,072</td>
#       <td id="T_6e049_row4_col1" class="data row4 col1" >4,220,041,327</td>
#       <td id="T_6e049_row4_col2" class="data row4 col2" >735,613,934</td>
#       <td id="T_6e049_row4_col3" class="data row4 col3" >542,720,651</td>
#       <td id="T_6e049_row4_col4" class="data row4 col4" >37,102,764</td>
#       <td id="T_6e049_row4_col5" class="data row4 col5" >393,078,250</td>
#     </tr>
#     <tr>
#       <th id="T_6e049_level0_row5" class="row_heading level0 row5" >2015</th>
#       <td id="T_6e049_row5_col0" class="data row5 col0" >1,201,102,442</td>
#       <td id="T_6e049_row5_col1" class="data row5 col1" >4,458,250,182</td>
#       <td id="T_6e049_row5_col2" class="data row5 col2" >741,535,608</td>
#       <td id="T_6e049_row5_col3" class="data row5 col3" >570,383,850</td>
#       <td id="T_6e049_row5_col4" class="data row5 col4" >40,403,283</td>
#       <td id="T_6e049_row5_col5" class="data row5 col5" >413,134,396</td>
#     </tr>
#     <tr>
#       <th id="T_6e049_level0_row6" class="row_heading level0 row6" >2020</th>
#       <td id="T_6e049_row6_col0" class="data row6 col0" >1,360,671,810</td>
#       <td id="T_6e049_row6_col1" class="data row6 col1" >4,663,086,535</td>
#       <td id="T_6e049_row6_col2" class="data row6 col2" >745,792,196</td>
#       <td id="T_6e049_row6_col3" class="data row6 col3" >594,236,593</td>
#       <td id="T_6e049_row6_col4" class="data row6 col4" >43,933,426</td>
#       <td id="T_6e049_row6_col5" class="data row6 col5" >431,530,043</td>
#     </tr>
#     <tr>
#       <th id="T_6e049_level0_row7" class="row_heading level0 row7" >2022</th>
#       <td id="T_6e049_row7_col0" class="data row7 col0" >1,426,730,932</td>
#       <td id="T_6e049_row7_col1" class="data row7 col1" >4,721,383,274</td>
#       <td id="T_6e049_row7_col2" class="data row7 col2" >743,147,538</td>
#       <td id="T_6e049_row7_col3" class="data row7 col3" >600,296,136</td>
#       <td id="T_6e049_row7_col4" class="data row7 col4" >45,038,554</td>
#       <td id="T_6e049_row7_col5" class="data row7 col5" >436,816,608</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.area(wp_df_gb, title='World Population (%) by Continent over the years', groupnorm='percent')
fig.show()
# Out:
# <div>                            <div id="814321c0-d316-479e-bb77-db49a89e5a27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("814321c0-d316-479e-bb77-db49a89e5a27")) {                    Plotly.newPlot(                        "814321c0-d316-479e-bb77-db49a89e5a27",                        [{"groupnorm":"percent","hovertemplate":"Continent=Africa<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Africa","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Africa","orientation":"v","showlegend":true,"stackgroup":"1","x":["1970","1980","1990","2000","2010","2015","2020","2022"],"xaxis":"x","y":[365444348,481536377,638150629,818946032,1055228072,1201102442,1360671810,1426730932],"yaxis":"y","type":"scatter"},{"groupnorm":"percent","hovertemplate":"Continent=Asia<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Asia","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Asia","orientation":"v","showlegend":true,"stackgroup":"1","x":["1970","1980","1990","2000","2010","2015","2020","2022"],"xaxis":"x","y":[2144906290,2635334228,3210563577,3735089604,4220041327,4458250182,4663086535,4721383274],"yaxis":"y","type":"scatter"},{"groupnorm":"percent","hovertemplate":"Continent=Europe<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Europe","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe","orientation":"v","showlegend":true,"stackgroup":"1","x":["1970","1980","1990","2000","2010","2015","2020","2022"],"xaxis":"x","y":[655923991,692527159,720320797,726093423,735613934,741535608,745792196,743147538],"yaxis":"y","type":"scatter"},{"groupnorm":"percent","hovertemplate":"Continent=North America<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"North America","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"North America","orientation":"v","showlegend":true,"stackgroup":"1","x":["1970","1980","1990","2000","2010","2015","2020","2022"],"xaxis":"x","y":[315434606,368293361,421266425,486069584,542720651,570383850,594236593,600296136],"yaxis":"y","type":"scatter"},{"groupnorm":"percent","hovertemplate":"Continent=Oceania<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Oceania","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"Oceania","orientation":"v","showlegend":true,"stackgroup":"1","x":["1970","1980","1990","2000","2010","2015","2020","2022"],"xaxis":"x","y":[19480270,22920240,26743822,31222778,37102764,40403283,43933426,45038554],"yaxis":"y","type":"scatter"},{"groupnorm":"percent","hovertemplate":"Continent=South America<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"South America","line":{"color":"#19d3f3"},"marker":{"symbol":"circle"},"mode":"lines","name":"South America","orientation":"v","showlegend":true,"stackgroup":"1","x":["1970","1980","1990","2000","2010","2015","2020","2022"],"xaxis":"x","y":[192947156,241789006,297146415,349634282,393078250,413134396,431530043,436816608],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth" ...

# %% [markdown]
# # 1. Plotly Express Choropleth
# This is the fast and simpler version to use, however there is limited functionality and customisation.

# %%
fig = px.choropleth(wp_df, locations = 'ISO-3',  
                    color = '1970', #select the population values
                    locationmode="ISO-3", #identify geolocation of countries using ISO-3
                    scope="world",
                    title = 'World Population by Country in 1970', 
                    hover_name="Country", #add hover title
                    hover_data = {'1970': False, #add or remove hover data
                                  'World Population Percentage':True,
                                  'Growth Rate':True,'Area (km²)':True,
                                  'Density (per km²)':True,'ISO-3':False,},
                    projection = 'hammer', #standard projection type is 'equirectangular'
                    color_continuous_scale=px.colors.sequential.Sunset)
 
fig.show()
# Out:
# <div>                            <div id="2a1b01f2-cd6b-4c98-8524-894e9cfe44ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a1b01f2-cd6b-4c98-8524-894e9cfe44ec")) {                    Plotly.newPlot(                        "2a1b01f2-cd6b-4c98-8524-894e9cfe44ec",                        [{"coloraxis":"coloraxis","customdata":[[10752971,0.52,1.0257,652230,63.0587,"AFG"],[2324731,0.04,0.9957,28748,98.8702,"ALB"],[13795915,0.56,1.0164,2381741,18.8531,"DZA"],[27075,0.0,0.9831,199,222.4774,"ASM"],[19860,0.0,1.01,468,170.5641,"AND"],[6029700,0.45,1.0315,1246700,28.5466,"AGO"],[6283,0.0,1.0066,91,174.2527,"AIA"],[64516,0.0,1.0058,442,212.1335,"ATG"],[23842803,0.57,1.0052,2780400,16.3683,"ARG"],[2534377,0.03,0.9962,29743,93.4831,"ARM"],[59106,0.0,0.9991,180,591.3611,"ABW"],[12595034,0.33,1.0099,7692024,3.4032,"AUS"],[7465301,0.11,1.002,83871,106.5877,"AUT"],[5425317,0.13,1.0044,86600,119.6082,"AZE"],[179129,0.01,1.0051,13943,29.4043,"BHS"],[222555,0.02,1.0061,765,1924.4876,"BHR"],[67541860,2.15,1.0108,147570,1160.035,"BGD"],[241397,0.0,1.0015,430,654.9651,"BRB"],[9170786,0.12,0.9955,207600,45.9295,"BLR"],[9629376,0.15,1.0038,30528,381.8111,"BEL"],[120905,0.01,1.0131,22966,17.6466,"BLZ"],[3023443,0.17,1.0274,112622,118.5635,"BEN"],[52019,0.0,1.0,54,1188.5926,"BMU"],[298894,0.01,1.0064,38394,20.3796,"BTN"],[4585693,0.15,1.012,1098581,11.1272,"BOL"],[3815561,0.04,0.9886,51209,63.1437,"BIH"],[592244,0.03,1.0162,582000,4.5194,"BWA"],[96369875,2.7,1.0046,8515767,25.2841,"BRA"],[9581,0.0,1.0059,151,207.3179,"VGB"],[133343,0.01,1.0081,5765,77.8841,"BRN"],[8582950,0.09,0.9849,110879,61.1654,"BGR"],[5611666,0.28,1.0259,272967,83.0641,"BFA"],[3497834,0.16,1.027,27834,463.0874,"BDI"],[6708525,0.21,1.0108,181035,92.6221,"KHM"],[6452787,0.35,1.0263,475442,58.7128,"CMR"],[21434577,0.48,1.0078,9984670,3.8513,"CAN"],[287262,0.01,1.0089,4033,147.0739,"CPV"],[10533,0.0,1.0084,264,260.25,"CYM"],[2067356,0.07,1.0224,622984,8.9555,"CAF"],[3667394,0.22,1.0316,1284000,13.8032,"TCD"],[9820481,0.25,1.0057,756102,25.9274,"CHL"],[822534450,17.88,1.0,9706961,146.8933,"CHN"],[20905254,0.65,1.0069,1141748,45.4339,"COL"],[242351,0.01,1.0184,1862,449.3953,"COM"],[20470,0.0,1.0005,236,72.0805,"COK"],[1855697,0.06,1.0052,51100,101.3861,"CRI"],[4492638,0.05,0.9927,56594,71.2153,"HRV"],[8869636,0.14,0.9961,109884,102.0366,"CUB"],[150385,0.0,1.0043,444,430.5473,"CUW"],[640804,0.02,1.0059,9251,135.2814,"CYP"],[9795744,0.13,0.9984,78865,133.0627,"CZE"],[4922963,0.07,1.0048,43094,136.4984,"DNK"],[144379,0.01,1.0138,23200,48.3125,"DJI"],[68895,0.0,1.0045,751,96.8535,"DMA"],[4475871,0.14,1.01,48671,230.7087,"DOM"],[20151733,1.24,1.0325,2344858,42.2244,"COD"],[6172215,0.23,1.0114,276841,65.0229,"ECU"],[34781986,1.39,1.0158,1002450,110.7188,"EGY"],[3619090,0.08,1.0035,21041,301.145,"SLV"],[316955,0.02,1.0247,28051,59.7094,"GNQ"],[1272748,0.05,1.0176,117600,31.3268,"ERI"],[1361999,0.02,0.998,45227,29.3201,"EST"],[442865,0.02,1.0079,17364,69.2047,"SWZ"],[28308246,1.55,1.0257,1104300,111.7268,"ETH"],[2274,0.0,1.0043,12173,0.3105,"FLK"],[38416,0.0,1.0038,1393,38.112,"FRO"],[527634,0.01,1.0056,18272,50.8847,"FJI"],[4606621,0.07,1.0009,338424,16.3722,"FIN"],[50523586,0.81,1.0015,551695,117.1419,"FRA"],[46484,0.0,1.0239,83534,3.6459,"GUF"],[117891,0.0,1.0074,4167,73.5011,"PYF"],[597192,0.03,1.0204,267668,8.9252,"GAB"],[528731,0.03,1.025,10689,253.1567,"GMB"],[4800426,0.05,0.9964,69700,53.7214,"GEO"],[78294583,1.05,0.9995,357114,233.4544,"DEU"],[8861895,0.42,1.0196,238533,140.3406,"GHA"],[26685,0.0,0.9994,6,5441.5,"GIB"],[8544873,0.13,0.9942,131990,78.68,"GRC"],[45434,0.0,1.004,2166086,0.0261,"GRL"],[98794,0.0,1.0066,344,364.6453,"GRD"],[318310,0.0,0.9992,1628,243.0909,"GLP"],[88300,0.0,1.0073,549,312.8852,"GUM"],[5453208,0.22,1.0134,108889,163.8725 ...

# %% [markdown]
# # 2. Plotly Graph Object (go.Choropleth)
# More customisation to create a clean and sleek choropleth.

# %%
df = pd.DataFrame()
#convert floats to str in a temporary df
for col in wp_df.columns:
    df[col] = wp_df[col].astype(str)

#formatting the hovertext input as a df
df['text'] = df['Country'] + '<br>' + \
            'World Population Percentage : ' + df['World Population Percentage'] + '<br>' + \
            'Growth Rate : ' + df['Growth Rate']

fig = go.Figure(data=go.Choropleth(
    locations = wp_df['ISO-3'],#using ISO-3 country codes
    z = wp_df['2022'], #data
    text = df['text'], #hovertext
    colorscale = 'Portland',
    marker_line_color='white',
    marker_line_width=0.5,
    colorbar_title = 'Country Population',
))

fig.update_layout(
    title_text='World Population in 2022',
    geo=dict(
        showframe=False, #removing the squareframe is much sleek
        showcoastlines=False, #so is removing the coastlines
        projection_type='equirectangular' #the standard map projection
    ),
    #geo_scope = 'asia', #used to set the scope of the map, activate this to focus on asia only
    annotations = [dict(
        x=0.55, #set the coordinates for the source reference
        y=0.1,
        xref='paper',
        yref='paper',
        text='Source: <a href="https://www.kaggle.com/datasets/iamsouravbanerjee/world-population-dataset">Kaggle: World Population Dataset</a>',
        showarrow = False
    )]
)

fig.show()
# Out:
# <div>                            <div id="6c6b6eb8-0b44-4090-8d31-794b2a58f507" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c6b6eb8-0b44-4090-8d31-794b2a58f507")) {                    Plotly.newPlot(                        "6c6b6eb8-0b44-4090-8d31-794b2a58f507",                        [{"colorbar":{"title":{"text":"Country Population"}},"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"locations":["AFG","ALB","DZA","ASM","AND","AGO","AIA","ATG","ARG","ARM","ABW","AUS","AUT","AZE","BHS","BHR","BGD","BRB","BLR","BEL","BLZ","BEN","BMU","BTN","BOL","BIH","BWA","BRA","VGB","BRN","BGR","BFA","BDI","KHM","CMR","CAN","CPV","CYM","CAF","TCD","CHL","CHN","COL","COM","COK","CRI","HRV","CUB","CUW","CYP","CZE","DNK","DJI","DMA","DOM","COD","ECU","EGY","SLV","GNQ","ERI","EST","SWZ","ETH","FLK","FRO","FJI","FIN","FRA","GUF","PYF","GAB","GMB","GEO","DEU","GHA","GIB","GRC","GRL","GRD","GLP","GUM","GTM","GGY","GIN","GNB","GUY","HTI","HND","HKG","HUN","ISL","IND","IDN","IRN","IRQ","IRL","IMN","ISR","ITA","CIV","JAM","JPN","JEY","JOR","KAZ","KEN","KIR","KWT","KGZ","LAO","LVA","LBN","LSO","LBR","LBY","LIE","LTU","LUX","MAC","MDG","MWI","MYS","MDV","MLI","MLT","MHL","MTQ","MRT","MUS","MYT","MEX","FSM","MDA","MCO","MNG","MNE","MSR","MAR","MOZ","MMR","NAM","NRU","NPL","NLD","NCL","NZL","NIC","NER","NGA","NIU","PRK","MKD","NFK","NOR","OMN","PAK","PLW","PSE","PAN","PNG","PRY","PER","PHL","POL","PRT","PRI","QAT","COG","REU","ROU","RUS","RWA","BLM","KNA","LCA","MAF","SPM","VCT","WSM","SMR","STP","SAU","SEN","SRB","SYC","SLE","SGP","SXM","SVK","SVN","SLB","SOM","ZAF","KOR","SSD","ESP","LKA","SDN","SUR","SWE","CHE","SYR","TWN","TJK","TZA","THA","TLS","TGO","TKL","TON","TTO","TUN","TUR","TKM","TCA","TUV","UGA","UKR","ARE","GBR","USA","VIR","URY","UZB","VUT","VAT","VEN","VNM","WLF","ESH","YEM","ZMB","ZWE"],"marker":{"line":{"color":"white","width":0.5}},"text":["Afghanistan<br>World Population Percentage : 0.52<br>Growth Rate : 1.0257","Albania<br>World Population Percentage : 0.04<br>Growth Rate : 0.9957","Algeria<br>World Population Percentage : 0.56<br>Growth Rate : 1.0164","American Samoa<br>World Population Percentage : 0.0<br>Growth Rate : 0.9831","Andorra<br>World Population Percentage : 0.0<br>Growth Rate : 1.01","Angola<br>World Population Percentage : 0.45<br>Growth Rate : 1.0315","Anguilla<br>World Population Percentage : 0.0<br>Growth Rate : 1.0066","Antigua and Barbuda<br>World Population Percentage : 0.0<br>Growth Rate : 1.0058","Argentina<br>World Population Percentage : 0.57<br>Growth Rate : 1.0052","Armenia<br>World Population Percentage : 0.03<br>Growth Rate : 0.9962","Aruba<br>World Population Percentage : 0.0<br>Growth Rate : 0.9991","Australia<br>World Population Percentage : 0.33<br>Growth Rate : 1.0099","Austria<br>World Population Percentage : 0.11<br>Growth Rate : 1.002","Azerbaijan<br>World Population Percentage : 0.13<br>Growth Rate : 1.0044","Bahamas<br>World Population Percentage : 0.01<br>Growth Rate : 1.0051","Bahrain<br>World Population Percentage : 0.02<br>Growth Rate : 1.0061","Bangladesh<br>World Population Percentage : 2.15<br>Growth Rate : 1.0108","Barbados<br>World Population Percentage : 0.0<br>Growth Rate : 1.0015","Belarus<br>World Population Percentage : 0.12<br>Growth Rate : 0.9955","Belgium<br>World Population Percentage : 0.15<br>Growth Rate : 1.0038","Belize<br>World Population Percentage : 0.01<br>Growth Rate : 1.0131","Benin<br>World Population Percentage : 0.17<br>Growth Rate : 1.0274","Bermuda<br>World Population Percentage : 0.0<br>Growth Rate : 1.0","Bhutan<br>World Population Percentage : 0.01<br>Growth Rate : 1.0064","Bolivia<br>World Population Percentage : 0.15<br>Growth Rate : 1 ...

# %% [markdown]
# # 3. Choropleth with Animation Frames
# # Preparing the data
# 1. First, use pandas melt function to create a year column
# 2. Next, use Plotly Express again, but include 'year' as animation_frame

# %%
wp_df_years = wp_df[['ISO-3','Country','1970','1980','1990','2000','2010','2015','2020','2022']]
print("Before Melting")
display(wp_df_years.head())
wp_df_melted = wp_df_years.melt(id_vars=["ISO-3", "Country"], var_name="Year", value_name="Population")
print("After Melting")
wp_df_melted.head(10)
# Out:
# Before Melting
#   ISO-3         Country      1970      1980      1990      2000      2010  \
# 0   AFG     Afghanistan  10752971  12486631  10694796  19542982  28189672
# 1   ALB         Albania   2324731   2941651   3295066   3182021   2913399
# 2   DZA         Algeria  13795915  18739378  25518074  30774621  35856344
# 3   ASM  American Samoa     27075     32886     47818     58230     54849
# 4   AND         Andorra     19860     35611     53569     66097     71519
#
#        2015      2020      2022
# 0  33753499  38972230  41128771
# 1   2882481   2866849   2842321
# 2  39543154  43451666  44903225
# 3     51368     46189     44273
# 4     71746     77700     79824
# After Melting
#   ISO-3              Country  Year  Population
# 0   AFG          Afghanistan  1970    10752971
# 1   ALB              Albania  1970     2324731
# 2   DZA              Algeria  1970    13795915
# 3   ASM       American Samoa  1970       27075
# 4   AND              Andorra  1970       19860
# 5   AGO               Angola  1970     6029700
# 6   AIA             Anguilla  1970        6283
# 7   ATG  Antigua and Barbuda  1970       64516
# 8   ARG            Argentina  1970    23842803
# 9   ARM              Armenia  1970     2534377

# %% [markdown]
# **Note:**
# 1. range_color is important, This is the fix the scale and avoid uto-scaling for each frame, adjusted themax scale down, otherwise only China and India will be visible due to the huge disparity in population compared to other nations.
# 2. animation_frame has been added

# %%
fig = px.choropleth(wp_df_melted, locations = 'ISO-3', color = 'Population', 
                    locationmode="ISO-3", scope="world", width = 800, height = 600,
                    title = 'World Population by Country (1970-2022) <br>with Animation Slider', 
                    hover_name="Country",
                    hover_data = {'ISO-3':False,},
                    projection = 'equirectangular',
                    range_color=(0, 400000000), #to fix the scale
                    animation_frame='Year', #added new column as the animation frame
                    color_continuous_scale=px.colors.sequential.Viridis)
 
fig.show()
# Out:
# <div>                            <div id="37b7404f-1224-402f-ae95-2e0d91a0aca1" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37b7404f-1224-402f-ae95-2e0d91a0aca1")) {                    Plotly.newPlot(                        "37b7404f-1224-402f-ae95-2e0d91a0aca1",                        [{"coloraxis":"coloraxis","customdata":[["AFG"],["ALB"],["DZA"],["ASM"],["AND"],["AGO"],["AIA"],["ATG"],["ARG"],["ARM"],["ABW"],["AUS"],["AUT"],["AZE"],["BHS"],["BHR"],["BGD"],["BRB"],["BLR"],["BEL"],["BLZ"],["BEN"],["BMU"],["BTN"],["BOL"],["BIH"],["BWA"],["BRA"],["VGB"],["BRN"],["BGR"],["BFA"],["BDI"],["KHM"],["CMR"],["CAN"],["CPV"],["CYM"],["CAF"],["TCD"],["CHL"],["CHN"],["COL"],["COM"],["COK"],["CRI"],["HRV"],["CUB"],["CUW"],["CYP"],["CZE"],["DNK"],["DJI"],["DMA"],["DOM"],["COD"],["ECU"],["EGY"],["SLV"],["GNQ"],["ERI"],["EST"],["SWZ"],["ETH"],["FLK"],["FRO"],["FJI"],["FIN"],["FRA"],["GUF"],["PYF"],["GAB"],["GMB"],["GEO"],["DEU"],["GHA"],["GIB"],["GRC"],["GRL"],["GRD"],["GLP"],["GUM"],["GTM"],["GGY"],["GIN"],["GNB"],["GUY"],["HTI"],["HND"],["HKG"],["HUN"],["ISL"],["IND"],["IDN"],["IRN"],["IRQ"],["IRL"],["IMN"],["ISR"],["ITA"],["CIV"],["JAM"],["JPN"],["JEY"],["JOR"],["KAZ"],["KEN"],["KIR"],["KWT"],["KGZ"],["LAO"],["LVA"],["LBN"],["LSO"],["LBR"],["LBY"],["LIE"],["LTU"],["LUX"],["MAC"],["MDG"],["MWI"],["MYS"],["MDV"],["MLI"],["MLT"],["MHL"],["MTQ"],["MRT"],["MUS"],["MYT"],["MEX"],["FSM"],["MDA"],["MCO"],["MNG"],["MNE"],["MSR"],["MAR"],["MOZ"],["MMR"],["NAM"],["NRU"],["NPL"],["NLD"],["NCL"],["NZL"],["NIC"],["NER"],["NGA"],["NIU"],["PRK"],["MKD"],["NFK"],["NOR"],["OMN"],["PAK"],["PLW"],["PSE"],["PAN"],["PNG"],["PRY"],["PER"],["PHL"],["POL"],["PRT"],["PRI"],["QAT"],["COG"],["REU"],["ROU"],["RUS"],["RWA"],["BLM"],["KNA"],["LCA"],["MAF"],["SPM"],["VCT"],["WSM"],["SMR"],["STP"],["SAU"],["SEN"],["SRB"],["SYC"],["SLE"],["SGP"],["SXM"],["SVK"],["SVN"],["SLB"],["SOM"],["ZAF"],["KOR"],["SSD"],["ESP"],["LKA"],["SDN"],["SUR"],["SWE"],["CHE"],["SYR"],["TWN"],["TJK"],["TZA"],["THA"],["TLS"],["TGO"],["TKL"],["TON"],["TTO"],["TUN"],["TUR"],["TKM"],["TCA"],["TUV"],["UGA"],["UKR"],["ARE"],["GBR"],["USA"],["VIR"],["URY"],["UZB"],["VUT"],["VAT"],["VEN"],["VNM"],["WLF"],["ESH"],["YEM"],["ZMB"],["ZWE"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Year=1970<br>Population=%{z}<extra></extra>","hovertext":["Afghanistan","Albania","Algeria","American Samoa","Andorra","Angola","Anguilla","Antigua and Barbuda","Argentina","Armenia","Aruba","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bermuda","Bhutan","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","British Virgin Islands","Brunei","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Cape Verde","Cayman Islands","Central African Republic","Chad","Chile","China","Colombia","Comoros","Cook Islands","Costa Rica","Croatia","Cuba","Curacao","Cyprus","Czech Republic","Denmark","Djibouti","Dominica","Dominican Republic","DR Congo","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Estonia","Eswatini","Ethiopia","Falkland Islands","Faroe Islands","Fiji","Finland","France","French Guiana","French Polynesia","Gabon","Gambia","Georgia","Germany","Ghana","Gibraltar","Greece","Greenland","Grenada","Guadeloupe","Guam","Guatemala","Guernsey","Guinea","Guinea-Bissau","Guyana","Haiti","Honduras","Hong Kong","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Isle of Man","Israel","Italy","Ivory Coast","Jamaica","Japan","Jersey","Jordan","Kazakhstan","Kenya","Kiribati","Kuwait","Kyrgyzstan","Laos","Latvia","Lebanon","Lesotho","Liberia","Libya","Liechtenstein","Lithuania","Luxembourg","Macau","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Marshall Islands","Marti ...

# %% [markdown]
# # 4. Multiple Choropleths

# %%
years = ['1970','1980','1990','2000','2010','2015','2020','2022']
rows = 4
cols = 2

#to create a 4 x 2 array
specs = [[{'type':'choropleth'} for n in np.arange(cols)] for i in np.arange(rows)] 

fig = make_subplots(rows=rows, cols=cols, 
                    specs = specs,
                    subplot_titles = years, vertical_spacing=0.1, horizontal_spacing=0.01)              

for n, year in enumerate(years):
    fig.add_trace(go.Choropleth(locations= wp_df['ISO-3'],
                                z = wp_df[year],
                                text = df['text'],
                                locationmode = 'ISO-3',
                                colorscale='viridis',
                                zmin = 0, zmax = 400000000,
                                hoverinfo='z+text'),
                                row = n//cols+1, col = n%cols+1)
    
fig.update_layout(title={'text':'World Population over the Years', 'xanchor':'center','x':0.5},
                 coloraxis_showscale=False, margin={'r':200,'t':60,'l':200,'b':0},
                  geo1={'showframe':False, 'showcoastlines':False},
                  geo2={'showframe':False, 'showcoastlines':False},
                  geo3={'showframe':False, 'showcoastlines':False},
                  geo4={'showframe':False, 'showcoastlines':False},
                  geo5={'showframe':False, 'showcoastlines':False},
                  geo6={'showframe':False, 'showcoastlines':False},
                  geo7={'showframe':False, 'showcoastlines':False},
                  geo8={'showframe':False, 'showcoastlines':False}
                 )

fig.update_traces(showscale=False)
fig.show()
# Out:
# <div>                            <div id="9352112a-edf1-4a72-a21f-f3ff4470d3f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9352112a-edf1-4a72-a21f-f3ff4470d3f7")) {                    Plotly.newPlot(                        "9352112a-edf1-4a72-a21f-f3ff4470d3f7",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"hoverinfo":"z+text","locationmode":"ISO-3","locations":["AFG","ALB","DZA","ASM","AND","AGO","AIA","ATG","ARG","ARM","ABW","AUS","AUT","AZE","BHS","BHR","BGD","BRB","BLR","BEL","BLZ","BEN","BMU","BTN","BOL","BIH","BWA","BRA","VGB","BRN","BGR","BFA","BDI","KHM","CMR","CAN","CPV","CYM","CAF","TCD","CHL","CHN","COL","COM","COK","CRI","HRV","CUB","CUW","CYP","CZE","DNK","DJI","DMA","DOM","COD","ECU","EGY","SLV","GNQ","ERI","EST","SWZ","ETH","FLK","FRO","FJI","FIN","FRA","GUF","PYF","GAB","GMB","GEO","DEU","GHA","GIB","GRC","GRL","GRD","GLP","GUM","GTM","GGY","GIN","GNB","GUY","HTI","HND","HKG","HUN","ISL","IND","IDN","IRN","IRQ","IRL","IMN","ISR","ITA","CIV","JAM","JPN","JEY","JOR","KAZ","KEN","KIR","KWT","KGZ","LAO","LVA","LBN","LSO","LBR","LBY","LIE","LTU","LUX","MAC","MDG","MWI","MYS","MDV","MLI","MLT","MHL","MTQ","MRT","MUS","MYT","MEX","FSM","MDA","MCO","MNG","MNE","MSR","MAR","MOZ","MMR","NAM","NRU","NPL","NLD","NCL","NZL","NIC","NER","NGA","NIU","PRK","MKD","NFK","NOR","OMN","PAK","PLW","PSE","PAN","PNG","PRY","PER","PHL","POL","PRT","PRI","QAT","COG","REU","ROU","RUS","RWA","BLM","KNA","LCA","MAF","SPM","VCT","WSM","SMR","STP","SAU","SEN","SRB","SYC","SLE","SGP","SXM","SVK","SVN","SLB","SOM","ZAF","KOR","SSD","ESP","LKA","SDN","SUR","SWE","CHE","SYR","TWN","TJK","TZA","THA","TLS","TGO","TKL","TON","TTO","TUN","TUR","TKM","TCA","TUV","UGA","UKR","ARE","GBR","USA","VIR","URY","UZB","VUT","VAT","VEN","VNM","WLF","ESH","YEM","ZMB","ZWE"],"text":["Afghanistan<br>World Population Percentage : 0.52<br>Growth Rate : 1.0257","Albania<br>World Population Percentage : 0.04<br>Growth Rate : 0.9957","Algeria<br>World Population Percentage : 0.56<br>Growth Rate : 1.0164","American Samoa<br>World Population Percentage : 0.0<br>Growth Rate : 0.9831","Andorra<br>World Population Percentage : 0.0<br>Growth Rate : 1.01","Angola<br>World Population Percentage : 0.45<br>Growth Rate : 1.0315","Anguilla<br>World Population Percentage : 0.0<br>Growth Rate : 1.0066","Antigua and Barbuda<br>World Population Percentage : 0.0<br>Growth Rate : 1.0058","Argentina<br>World Population Percentage : 0.57<br>Growth Rate : 1.0052","Armenia<br>World Population Percentage : 0.03<br>Growth Rate : 0.9962","Aruba<br>World Population Percentage : 0.0<br>Growth Rate : 0.9991","Australia<br>World Population Percentage : 0.33<br>Growth Rate : 1.0099","Austria<br>World Population Percentage : 0.11<br>Growth Rate : 1.002","Azerbaijan<br>World Population Percentage : 0.13<br>Growth Rate : 1.0044","Bahamas<br>World Population Percentage : 0.01<br>Growth Rate : 1.0051","Bahrain<br>World Population Percentage : 0.02<br>Growth Rate : 1.0061","Bangladesh<br>World Population Percentage : 2.15<br>Growth Rate : 1.0108","Barbados<br>World Population Percentage : 0.0<br>Growth Rate : 1.0015","Belarus<br>World Population Percentage : 0.12<br>Growth Rate : 0.9955","Belgium<br>World Population Percentage : 0.15<br>Growth Rate : 1.0038","Belize<br>World Population Percentage : 0.01<br>Growth Rate : 1.0131","Benin<br>World Population Percentage : 0.17<br>Growth Rate : 1.0274","Bermuda<br>World Population Percentage : 0.0<br>Growth Rate : 1.0","Bhutan<br>World Population Per ...
